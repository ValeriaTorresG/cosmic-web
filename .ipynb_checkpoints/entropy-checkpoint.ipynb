# %%
import numpy as np
from scipy.spatial import Delaunay
import pandas as pd
from itertools import combinations
import os
from scipy.stats import ecdf
from sklearn.decomposition import PCA
from astropy.table import Table as t
import glob
from scipy.stats import norm
from scipy.stats import gaussian_kde

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.tri as mtri
matplotlib.rcParams['figure.dpi'] = 360
# matplotlib.rcParams['text.usetex'] = True
# os.environ['PATH'] = '/Library/TeX/texbin:' + os.environ['PATH']

plt.rcParams.update({
    'font.family': 'serif',
    'font.size': 12,
    'axes.labelsize': 12,
    'xtick.labelsize': 10,
    'ytick.labelsize': 10,
    'legend.fontsize': 10,
})
# plt.style.use('default')
cmap = sns.color_palette('mako', as_cmap=True)
cmap

# %% [markdown]
# ### PDF Plot

# %%
base_url = './data/results/'
os.listdir = os.path.dirname(base_url)

# %%
pattern = os.path.join(base_url, 'rosette_*.csv')
files = sorted(glob.glob(pattern))
len(files)
# Out:
# 20

# %%
df['H'].max()
# Out:
# 0.5350686325115535

# %%
H_all = []
for fpath in files:
    print(fpath)
    df = pd.read_csv(fpath)
    # print(df['H'].describe())
    H_all.extend(df['H'].values)

H_all.sort()
# Out:
# ./data/results/rosette_0.csv
# ./data/results/rosette_1.csv
# ./data/results/rosette_10.csv
# ./data/results/rosette_11.csv
# ./data/results/rosette_12.csv
# ./data/results/rosette_13.csv
# ./data/results/rosette_14.csv
# ./data/results/rosette_15.csv
# ./data/results/rosette_16.csv
# ./data/results/rosette_17.csv
# ./data/results/rosette_18.csv
# ./data/results/rosette_19.csv
# ./data/results/rosette_2.csv
# ./data/results/rosette_3.csv
# ./data/results/rosette_4.csv
# ./data/results/rosette_5.csv
# ./data/results/rosette_6.csv
# ./data/results/rosette_7.csv
# ./data/results/rosette_8.csv
# ./data/results/rosette_9.csv

# %%
H_all = np.array(H_all)

# %%
plt.figure(figsize=(6,4))

fns = sorted(glob.glob('data/results/rosette_*.csv'))
for f in fns:
    df = pd.read_csv(f)
    H = df['H'].values

    pdf, edges = np.histogram(H, bins=25, density=True)
    centers = 0.5*(edges[:-1] + edges[1:])
    rosette = f.split('/')[-1].split('_')[-1].split('.')[0]
    
    mask = pdf > 0
    
    plt.plot(centers[mask], pdf[mask], lw=1, label=f'Rosette {rosette}')
plt.xlabel('H')
plt.ylabel('PDF')
plt.legend(ncol=3, loc='upper left', fontsize=8)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 4))

fns = sorted(glob.glob('data/results/rosette_*.csv'))
for f in fns:
    df = pd.read_csv(f)
    H = df['H'].values

    kde = gaussian_kde(H)
    
    x_vals = np.linspace(min(H), max(H), 200)
    pdf_vals = kde(x_vals)

    rosette = f.split('/')[-1].split('_')[-1].split('.')[0]

    plt.plot(x_vals, pdf_vals, lw=1, label=f'Rosette {rosette}')

plt.xlabel('H', fontsize=14)
plt.ylabel('PDF', fontsize=14)
plt.legend(ncol=3, loc='upper left', fontsize=8)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# --------

# %%
pdf, edges = np.histogram(H, bins=25, density=True)
centers = 0.5*(edges[:-1] + edges[1:])

plt.figure(figsize=(6,4))
plt.plot(centers[mask], pdf[mask], marker='o', linestyle='-')  # <–– fíjate: primero ‘centers’, luego ‘pdf’
plt.xlabel('$H$')
plt.ylabel('PDF$(H)$')
plt.tight_layout()
plt.show()
